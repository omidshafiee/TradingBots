# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import yfinance as yf

# %%
# Define the ticker symbol
ticker_symbol = "AAPL"

# Create a ticker object
ticker = yf.Ticker(ticker_symbol)

# %%
# Download historical data

# historical_data = ticker.history(start='1990-01-01', end='2023-12-31', interval='1d')

historical_data = ticker.history(period='7d', interval='1h')
# Out:
# $AAPL: possibly delisted; No price data found  (period=7d)

# %%
historical_data.shape
# Out:
# (0, 6)

# %%
historical_data.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-12-22 00:00:00-05:00  194.667221  194.896627  192.463035  193.091385
# 2023-12-26 00:00:00-05:00  193.101342  193.380606  192.323393  192.542816
# 2023-12-27 00:00:00-05:00  191.984293  192.991634  190.587962  192.642548
# 2023-12-28 00:00:00-05:00  193.629953  194.148591  192.662500  193.071426
# 2023-12-29 00:00:00-05:00  193.390581  193.889267  191.226284  192.024185
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-12-22 00:00:00-05:00  37122800        0.0           0.0
# 2023-12-26 00:00:00-05:00  28919300        0.0           0.0
# 2023-12-27 00:00:00-05:00  48087700        0.0           0.0
# 2023-12-28 00:00:00-05:00  34049900        0.0           0.0
# 2023-12-29 00:00:00-05:00  42628800        0.0           0.0

# %%
historical_data['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data = yf.download(ticker_symbol, period='1y', interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-22  173.979996  174.710007  173.449997  174.199997  173.279739
# 2023-05-23  173.130005  173.380005  171.279999  171.559998  170.653702
# 2023-05-24  171.089996  172.419998  170.520004  171.839996  170.932220
# 2023-05-25  172.410004  173.899994  171.690002  172.990005  172.076157
# 2023-05-26  173.320007  175.770004  173.110001  175.429993  174.503250
#
#               Volume
# Date
# 2023-05-22  43570900
# 2023-05-23  50747300
# 2023-05-24  45143500
# 2023-05-25  56058300
# 2023-05-26  54835000

# %%
historical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8565 entries, 1990-01-02 00:00:00-05:00 to 2023-12-29 00:00:00-05:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          8565 non-null   float64
#  1   High          8565 non-null   float64
#  2   Low           8565 non-null   float64
#  3   Close         8565 non-null   float64
#  4   Volume        8565 non-null   int64
#  5   Dividends     8565 non-null   float64
#  6   Stock Splits  8565 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 535.3 KB

# %%
tickers_list = ["AAPL", "MSFT", "GOOGL"]
multiple_data = yf.download(tickers_list, period="1mo")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
multiple_data
# Out:
# Price        Adj Close                               Close              \
# Ticker            AAPL       GOOGL        MSFT        AAPL       GOOGL
# Date
# 2024-04-22  165.615356  156.279999  400.238068  165.839996  156.279999
# 2024-04-23  166.673920  158.259995  406.836182  166.899994  158.259995
# 2024-04-24  168.791061  159.130005  408.323486  169.020004  159.130005
# 2024-04-25  169.659882  156.000000  398.321533  169.889999  156.000000
# 2024-04-26  169.070679  171.949997  405.588440  169.300003  171.949997
# 2024-04-29  173.264984  166.149994  401.525757  173.500000  166.149994
# 2024-04-30  170.099289  162.779999  388.628998  170.330002  162.779999
# 2024-05-01  169.070679  163.860001  394.228912  169.300003  163.860001
# 2024-05-02  172.795624  166.619995  397.123688  173.029999  166.619995
# 2024-05-03  183.131607  167.240005  405.927826  183.380005  167.240005
# 2024-05-06  181.463882  168.100006  412.795441  181.710007  168.100006
# ...

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Read from Dukascopy

# %%
df = pd.read_csv('../dataset/dukascopy/EURUSD_Candlestick_1_Hour_BID_01.05.2023-18.05.2024.csv')

# %%
df.head()
# Out:
#                   Gmt time     Open     High      Low    Close     Volume
# 0  01.05.2023 00:00:00.000  1.10106  1.10143  1.10045  1.10055  8127.1401
# 1  01.05.2023 01:00:00.000  1.10055  1.10084  1.10020  1.10040  7000.5898
# 2  01.05.2023 02:00:00.000  1.10037  1.10081  1.10007  1.10081  3727.6499
# 3  01.05.2023 03:00:00.000  1.10081  1.10140  1.10053  1.10140  4344.2002
# 4  01.05.2023 04:00:00.000  1.10143  1.10143  1.10032  1.10062  4607.4600

# %%
df.shape
# Out:
# (9216, 6)
